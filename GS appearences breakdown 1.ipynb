# %%
import pandas as pd

# %%
data = pd.read_csv('GS23_appearence.csv')
data.head()
# Out:
#           Player  Frequency
# 0      I Świątek          4
# 1     A Blinkova          4
# 2  E Alexandrova          4
# 3        D Parry          4
# 4      M Linette          4

# %%
data.shape
# Out:
# (190, 2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = data.value_counts(subset = 'Frequency')

# %%
df
# Out:
# Frequency
# 4    73
# 1    47
# 2    37
# 3    33
# Name: count, dtype: int64

# %%
plt.pie(df, labels=df.index, autopct='%1.1f%%', startangle=90)
plt.title('Apearence breakdowns of players in GS 2023')
plt.show()
plt.savefig("Viz1.jpg")
