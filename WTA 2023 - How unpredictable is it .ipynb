# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
wta = pd.read_csv('wta_matches_2023.csv')

wta.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2023-9900   United Cup    Hard         18             I      20230102
# 1  2023-9900   United Cup    Hard         18             I      20230102
# 2  2023-9900   United Cup    Hard         18             I      20230102
# 3  2023-9900   United Cup    Hard         18             I      20230102
# 4  2023-9900   United Cup    Hard         18             I      20230102
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        298     202468          NaN          NaN  ...    43.0     20.0
# 1        297     201619          NaN          NaN  ...    32.0     14.0
# 2        294     202468          NaN          NaN  ...    26.0     10.0
# 3        293     201619          NaN          NaN  ...    47.0     29.0
# 4        290     203354          NaN          NaN  ...    53.0     37.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# ...

# %%
wta.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
plt.figure(figsize = (25,10))
sns.countplot(x='winner_ioc', data=wta)
plt.savefig('wta2023_1.png')

# %%
wta['winner_ioc'].unique()
# Out:
# array(['USA', 'ITA', 'GRE', 'CRO', 'POL', 'BEL', 'SUI', 'CZE', 'ESP',
#        'GBR', 'BRA', 'FRA', 'BLR', 'TUN', 'ROU', 'UKR', 'RUS', 'KAZ',
#        'CHN', 'LAT', 'CAN', 'EST', 'MNE', 'SVK', 'AUT', 'GER', 'COL',
#        'SLO', 'HUN', 'AUS', 'ARG', 'JPN', 'KOR', 'SWE', 'EGY', 'DEN',
#        'BUL', 'SRB', 'NED', 'TUR', 'MDA', 'IND', 'LIE', 'NOR', 'PER',
#        'GUA', 'BOL', 'CHI', 'THA', 'LVA', 'BIH', 'MLT', 'POR', 'ISR',
#        'IRL', 'GEO', 'RSA', 'LTU', 'MEX'], dtype=object)

# %%
wta['winner_ioc'].value_counts()
# Out:
# winner_ioc
# USA    394
# RUS    310
# CZE    252
# CHN    126
# ITA    126
# UKR    112
# POL    110
# FRA    108
# BLR     98
# GER     81
# ESP     81
# KAZ     73
# ROU     69
# CAN     66
# BEL     62
# CRO     57
# SUI     51
# GBR     50
# GRE     47
# LAT     42
# BRA     42
# TUN     36
# COL     33
# JPN     30
# HUN     29
# ARG     27
# SVK     27
# AUS     23
# SWE     21
# SLO     19
# EST     19
# DEN     18
# EGY     16
# NED     16
# AUT     16
# SRB     14
# BUL     12
# KOR      9
# LTU      9
# MNE      8
# BIH      7
# POR      7
# GEO      6
# THA      6
# TUR      6
# MLT      6
# PER      5
# CHI      5
# IND      5
# RSA      3
# NOR      3
# BOL      2
# IRL      2
# GUA      2
# MEX      2
# LVA      1
# ISR      1
# LIE      1
# MDA      1
# Name: count, dtype: int64

# %%
wta['upset'] = np.where(wta['loser_rank'] > wta['winner_rank'], 'Yes', 'No')

# %%
wta.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2023-9900   United Cup    Hard         18             I      20230102
# 1  2023-9900   United Cup    Hard         18             I      20230102
# 2  2023-9900   United Cup    Hard         18             I      20230102
# 3  2023-9900   United Cup    Hard         18             I      20230102
# 4  2023-9900   United Cup    Hard         18             I      20230102
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stWon l_2ndWon  \
# 0        298     202468          NaN          NaN  ...     20.0     12.0
# 1        297     201619          NaN          NaN  ...     14.0      6.0
# 2        294     202468          NaN          NaN  ...     10.0      5.0
# 3        293     201619          NaN          NaN  ...     29.0      5.0
# 4        290     203354          NaN          NaN  ...     37.0     22.0
#
#    l_SvGms l_bpSaved  l_bpFaced  winner_rank  winner_rank_points loser_rank  \
# ...

# %%
# Count occurrences of 'Yes' and 'No'
count_result = wta['upset'].value_counts()

# Plot a pie chart
plt.pie(count_result, labels=count_result.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Did the higher ranked player win??')
plt.show()

# %%
grandslam = wta[wta['tourney_level'] == 'G']
# Count occurrences of 'Yes' and 'No'
count_result = grandslam['upset'].value_counts()

# Plot a pie chart
plt.pie(count_result, labels=count_result.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Did the higher ranked player win?? (at GrandSlams)( WTA)')
plt.show()

# %%
wta[['tourney_level','tourney_name']]
# Out:
#      tourney_level      tourney_name
# 0                I        United Cup
# 1                I        United Cup
# 2                I        United Cup
# 3                I        United Cup
# 4                I        United Cup
# ...            ...               ...
# 2805             D  BJK Cup Playoffs
# 2806             D  BJK Cup Playoffs
# 2807             D  BJK Cup Playoffs
# 2808             D  BJK Cup Playoffs
# 2809             D  BJK Cup Playoffs
#
# [2810 rows x 2 columns]

# %%
wta['tourney_level'].unique()
# Out:
# array(['I', 'P', 'G', 'PM', 'F', 'D'], dtype=object)

# %%
grandslam = wta[wta['tourney_level'] != 'G']
# Count occurrences of 'Yes' and 'No'
count_result = grandslam['upset'].value_counts()

# Plot a pie chart
plt.pie(count_result, labels=count_result.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Did the higher ranked player win?? (at GrandSlams)')
plt.show()

# %%
grandslam = wta[wta['tourney_level'] == 'I']
# Count occurrences of 'Yes' and 'No'
count_result = grandslam['upset'].value_counts()

# Plot a pie chart
plt.pie(count_result, labels=count_result.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Did the higher ranked player win?? (at Internationals)')
plt.show()

# %%
grandslam = wta[wta['tourney_level'] == 'P']
# Count occurrences of 'Yes' and 'No'
count_result = grandslam['upset'].value_counts()

# Plot a pie chart
plt.pie(count_result, labels=count_result.index, autopct='%1.1f%%', startangle=90, colors=['blue', 'yellow'])
plt.title('Did the higher ranked player win?? (at premiers)')
plt.show()

# %%
grandslam = wta[wta['tourney_level'] == 'PM']
# Count occurrences of 'Yes' and 'No'
count_result = grandslam['upset'].value_counts()

# Plot a pie chart
plt.pie(count_result, labels=count_result.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title("Did the higher ranked player win?? (at PM's)")
plt.show()

# %%
atp = pd.read_csv('atp_matches_2023.csv')

# %%
atp['upsets'] = np.where(atp['loser_rank'] > atp['winner_rank'], 'No', 'Yes')

# %%
# Count occurrences of 'Yes' and 'No'
count_result = atp['upsets'].value_counts()

# Plot a pie chart
plt.pie(count_result, labels=count_result.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Did the higher ranked player win?? (ATP)')
plt.show()

# %%
grandslam = atp[atp['tourney_level'] == 'G']
# Count occurrences of 'Yes' and 'No'
count_result = grandslam['upsets'].value_counts()

# Plot a pie chart
plt.pie(count_result, labels=count_result.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Did the higher ranked player win?? (at GrandSlams) (ATP)')
plt.show()
